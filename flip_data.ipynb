# %%
PATH = r"/datasets/fpl/train/"
import pandas as pd
import numpy as np
from os import listdir, getcwd
cwd = getcwd()

# %%
datasets_csv = listdir(cwd + PATH)
for i,json_object in enumerate(datasets_csv):
    #print(json_object)
    df = pd.read_csv(cwd + PATH + json_object, sep='\t',)
    print(df.iloc[0])
# Out:
# 18                      23.000000
# 10                      10.000000
# 784.7194999999998      766.417000
# 415.8115               427.538500
# 41.97128212540099       44.453109
# 633.555                727.361000
# 362.439                341.420000
# 615.1709999999999      703.880000
# 403.981                383.145000
# 0.0                      0.000000
# 0.0.1                    0.000000
# 617.908                727.357000
# 490.148                469.369000
# 612.741                706.447000
# 424.909                403.948000
# 633.408                722.156000
# 425.0                  404.067000
# 630.854                727.359000
# 458.782                443.084000
# 623.0880000000001      716.982000
# 383.098                359.693000
# 641.2869999999999      742.954000
# 383.173                359.778000
# 0.0.2                    0.000000
# 0.0.3                    0.000000
# 654.245                758.586000
# 364.884                341.532000
# ...
